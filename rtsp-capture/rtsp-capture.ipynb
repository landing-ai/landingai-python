# %% [markdown]
# # About
# xxx

# %%
import sys, os
sys.path.append("../modules/src")

# %%
import cv2
from matplotlib import pyplot as plt
from IPython.display import Image

# url = "rtsp://guest:joe2@camara-wyze1:554/live" # Wyze v3 camera (with RTSP Firmware)
# url = "rtsp://guest:simple234@192.168.14.19:554/ISAPI/Streaming/channels/201/picture" # Hikvision DVR back
url = "rtsp://guest:simple234@192.168.14.19:554/ISAPI/Streaming/channels/1701/picture" # Hikvision DVR driveway
vcap = cv2.VideoCapture(url)
if not vcap.isOpened():
    print("Cannot open camera")
    exit()

# Capture frame-by-frame
ret, frame = vcap.read()
# if frame is read correctly ret is True
if not ret:
    print("Can't receive frame (stream end?). Exiting ...")
    exit()
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
# show camera frame
plt.imshow(frame)
plt.title(url)
plt.show()

# When everything done, release the capture
vcap.release()
cv2.destroyAllWindows()
# Out:
# [rtsp @ 0x563df4ecd600] Error parsing AU headers
# [rtsp @ 0x563df4ecd600] Error parsing AU headers
# [rtsp @ 0x563df4ecd600] Error parsing AU headers
# [rtsp @ 0x563df4ecd600] Error parsing AU headers
# [rtsp @ 0x563df4ecd600] Error parsing AU headers
# [rtsp @ 0x563df4ecd600] Error parsing AU headers
# [rtsp @ 0x563df4ecd600] Error parsing AU headers
# [rtsp @ 0x563df4ecd600] Error parsing AU headers
# [rtsp @ 0x563df4ecd600] Error parsing AU headers
# [rtsp @ 0x563df4ecd600] Error parsing AU headers
# [rtsp @ 0x563df4ecd600] Error parsing AU headers
# [rtsp @ 0x563df4ecd600] Error parsing AU headers
# [rtsp @ 0x563df4ecd600] Error parsing AU headers
# [rtsp @ 0x563df4ecd600] Error parsing AU headers
# [rtsp @ 0x563df4ecd600] Error parsing AU headers
# [rtsp @ 0x563df4ecd600] Error parsing AU headers
# [rtsp @ 0x563df4ecd600] Error parsing AU headers
# [rtsp @ 0x563df4ecd600] Error parsing AU headers
# [rtsp @ 0x563df4ecd600] Error parsing AU headers
# ...

# %%
from landingai import Predictor

Predictor.url = 'https://predict.app.staging.landing.ai/inference/v1/predict'
        
api_key = "k5hgo98gf99qipbmnmgu6ze5nnvtoet"
api_secret = "a94fy3cf3ier53vz1x11fx02ztv1wa81r86z77cuaju97wlvxkw9liv3kfk02a"

predictor = Predictor("4f59f362-d136-44df-94c0-1ed17fc5aee6", api_key, api_secret)

# frame = cv2.imread(r"/Users/william/Sync/Landing/Datasets/debris/cereal_1.jpg")

print(predictor.predict(frame))
# Out:
# {'backbonetype': None, 'backbonepredictions': None, 'predictions': {'6b7e635a-7ead-40b2-9f02-56feca2aab9f': {'score': 0.7778096199035645, 'defect_id': 2525479, 'coordinates': {'xmin': 3, 'ymin': 148, 'xmax': 387, 'ymax': 1068}, 'labelIndex': 2, 'labelName': 'Door open'}}, 'type': 'ObjectDetectionPrediction', 'latency': {'preprocess_s': 0.004092216491699219, 'infer_s': 0.1742238998413086, 'postprocess_s': 1.9073486328125e-05, 'serialize_s': 0.0031795501708984375, 'input_conversion_s': 0.03669476509094238, 'model_loading_s': 5.336428880691528}, 'model_id': '3ded0fb0-7cda-43b3-a208-23eef8000131'}
